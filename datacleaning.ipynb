# %%
import numpy as np
import pandas as pd

# %%
hfi = pd.read_csv('hfi.csv')
hfi.head()
# Out:
#    year ISO_code  countries                         region  pf_rol_procedural  \
# 0  2016      ALB    Albania                 Eastern Europe           6.661503
# 1  2016      DZA    Algeria     Middle East & North Africa                NaN
# 2  2016      AGO     Angola             Sub-Saharan Africa                NaN
# 3  2016      ARG  Argentina  Latin America & the Caribbean           7.098483
# 4  2016      ARM    Armenia        Caucasus & Central Asia                NaN
#
#    pf_rol_civil  pf_rol_criminal    pf_rol  pf_ss_homicide  \
# 0      4.547244         4.666508  5.291752        8.920429
# 1           NaN              NaN  3.819566        9.456254
# 2           NaN              NaN  3.451814        8.060260
# 3      5.791960         4.343930  5.744791        7.622974
# 4           NaN              NaN  5.003205        8.808750
#
#    pf_ss_disappearances_disap  ...  ef_regulation_business_bribes  \
# 0                        10.0  ...                       4.050196
# ...

# %%
hfi = hfi[hfi['year'] == 2016]

# %%
hfi = hfi.rename(columns={'countries': 'country', 'pf_ss_women_missing':'missing_women',
                         'pf_ss_women':'womens_security', 'pf_movement_women':'womens_movement'})

# %%
hfi = hfi[['country','ISO_code', 'region', 'hf_score', 'hf_rank', 'ef_score','ef_rank', 'pf_score','pf_rank', 'pf_rol_criminal',
          'missing_women','womens_security', 'womens_movement']]
hfi.head()
# Out:
#      country ISO_code                         region  hf_score  hf_rank  \
# 0    Albania      ALB                 Eastern Europe  7.568140     48.0
# 1    Algeria      DZA     Middle East & North Africa  5.135886    155.0
# 2     Angola      AGO             Sub-Saharan Africa  5.640662    142.0
# 3  Argentina      ARG  Latin America & the Caribbean  6.469848    107.0
# 4    Armenia      ARM        Caucasus & Central Asia  7.241402     57.0
#
#    ef_score  ef_rank  pf_score  pf_rank  pf_rol_criminal  missing_women  \
# 0      7.54     34.0  7.596281     57.0         4.666508            7.5
# 1      4.99    159.0  5.281772    147.0              NaN            7.5
# 2      5.17    155.0  6.111324    117.0              NaN           10.0
# 3      4.84    160.0  8.099696     42.0         4.343930           10.0
# 4      7.57     29.0  6.912804     84.0              NaN            5.0
#
#    womens_security  womens_movement
# 0         7.500000              5.0
# ...

# %%
gii = pd.read_csv('GII2015.csv')
gii.head()
# Out:
#    HDI Rank (2015)      Country   2000   2005   2010   2011   2012   2013  \
# 0              169  Afghanistan    NaN  0.739  0.724  0.713  0.701  0.689
# 1               75      Albania  0.381  0.332  0.273  0.279  0.281  0.272
# 2               83      Algeria  0.627  0.561  0.523  0.514  0.432  0.429
# 3               45    Argentina  0.422  0.374  0.370  0.367  0.366  0.364
# 4               84      Armenia  0.467  0.406  0.344  0.338  0.317  0.308
#
#     2014   2015
# 0  0.676  0.667
# 1  0.267  0.267
# 2  0.429  0.429
# 3  0.364    NaN
# 4  0.299  0.293

# %%
gii = gii.rename(columns={'HDI Rank (2015)': 'hdi_rank', 'Country':'country'})
gii = gii[['country','hdi_rank', '2015']]
gii.head()
# gii['2015'].isna().sum()
# Out:
#        country  hdi_rank   2015
# 0  Afghanistan       169  0.667
# 1      Albania        75  0.267
# 2      Algeria        83  0.429
# 3    Argentina        45    NaN
# 4      Armenia        84  0.293

# %%
# Out:
# 4
